# %%
import collections
import requests
from bs4 import BeautifulSoup
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/ethanyu/VSCodeProjects/PennPlan/Backend/course_prereq.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/Users/ethanyu/VSCodeProjects/PennPlan/Backend/course_prereq.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import collections
# ----> <a href='vscode-notebook-cell:/Users/ethanyu/VSCodeProjects/PennPlan/Backend/course_prereq.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import requests
#       <a href='vscode-notebook-cell:/Users/ethanyu/VSCodeProjects/PennPlan/Backend/course_prereq.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from bs4 import BeautifulSoup
#       <a href='vscode-notebook-cell:/Users/ethanyu/VSCodeProjects/PennPlan/Backend/course_prereq.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import json
#
# ModuleNotFoundError: No module named 'requests'

# %%
# Get all the class links
url = "https://catalog.upenn.edu/courses/"

response = requests.get(url)
header = "https://catalog.upenn.edu"
course_links = []

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    course_div = soup.find_all('div', class_='az_sitemap')

    course_uls = course_div[0].find_all('ul', class_=False)

    # Get and store all the course links
    for course_ul in course_uls:
        course_lis = course_ul.find_all('li', class_=False)
        for course_li in course_lis:
            a_elements = course_li.find_all('a')
            href_value = a_elements[0].get('href')
            course_links.append(header + href_value)
else:
    print("Failed to retrieve the page. Status code:", response.status_code)

# %%
def get_course_number(url):
    response = requests.get(url)
    course_numbers = []

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        course_listings = soup.find_all('div', class_='courseblock')

        for course in course_listings:
            p_tags = course.find_all('p')
            
            course_info = p_tags[0].text
            dept = course_info.split('\xa0')[0]
            course_number = course_info.split('\xa0')[1].split(' ')[0]
            
            course_numbers.append(dept + " " + course_number)
    else:
        print("Failed to retrieve the page. Status code:", response.status_code)    
    
    return course_numbers

# %%
all_course_numbers = []

for course_link in course_links:
    course_numbers = get_course_number(course_link)
    all_course_numbers.extend(course_numbers)

all_course_numbers_set = set(all_course_numbers)

# %%
# Course relations dictionary 
course_relations = {}
for course_number in all_course_numbers:
    course_relations[course_number] = set()

# %%
# Fill in the relationships
def update_relationships(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        course_listings = soup.find_all('div', class_='courseblock')

        for course in course_listings:
            p_tags = course.find_all('p')


            if len(p_tags) < 5 or not p_tags[-2].text.startswith("Prerequisite: "):
                continue
        
                
            cur_course = p_tags[0].text.split('  ')[0].replace('\xa0', ' ')


            # Split the strings by AND
            whole_string = p_tags[-2].text[14:]
            prerequisites = whole_string.split("AND")

            modified_prerequisites = []
            for prerequisite in prerequisites:
                prerequisite = prerequisite.replace("\xa0", " ").strip()
                modified_prerequisites.append(prerequisite)

            prerequisites = modified_prerequisites.copy()

            # Deal with OR cases
            modified_prerequisites = []
            for prerequisite in prerequisites:
                prerequisite = prerequisite.strip('()')
                prerequisite_parts = prerequisite.split('OR')
                first_prerequisite = prerequisite_parts[0].strip()
                modified_prerequisites.append(first_prerequisite)

            
            # Miscellaneous words
            modified_prerequisites = {prerequisite for prerequisite in modified_prerequisites if prerequisite in all_course_numbers_set}

            course_relations[cur_course].update(modified_prerequisites)


    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

# %%
# Fill in the relationships
def update_relationships(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        course_listings = soup.find_all('div', class_='courseblock')

        for course in course_listings:
            p_tags = course.find_all('p')

            if len(p_tags) < 5 or not p_tags[-2].text.startswith("Prerequisite: "):
                continue

            # Get the current course
            cur_course = p_tags[0].text.split('  ')[0].replace('\xa0', ' ')


            # Extract prerequisites and clean them
            whole_string = p_tags[-2].text[14:]
            prerequisites = whole_string.split("AND")

            modified_prerequisites = []
            for prerequisite in prerequisites:
                prerequisite = prerequisite.replace("\xa0", " ").strip('()').split('OR')[0].strip()
                modified_prerequisites.append(prerequisite)

            # Filter out non-existent prerequisites
            modified_prerequisites = {prerequisite for prerequisite in modified_prerequisites if prerequisite in all_course_numbers_set}
            course_relations[cur_course].update(modified_prerequisites)

    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

# %%
for course_link in course_links:
    update_relationships(course_link)

# %%
for course, prerequisites in course_relations.items():
    course_relations[course] = list(prerequisites)

with open('prerequisites.json', 'w') as f:
    json.dump(course_relations, f)

# %%
course_relations
# Out:
# {'ACFD 6000': set(),
#  'ACFD 6010': set(),
#  'ACFD 6020': set(),
#  'ACFD 6030': set(),
#  'ACFD 6999': set(),
#  'ACCT 1010': set(),
#  'ACCT 1020': set(),
#  'ACCT 2110': set(),
#  'ACCT 2120': {'ACCT 1010'},
#  'ACCT 2420': {'ACCT 1010'},
#  'ACCT 2430': {'ACCT 1010'},
#  'ACCT 2640': {'ACCT 1010', 'BEPP 2500'},
#  'ACCT 2700': {'ACCT 1010', 'STAT 1020'},
#  'ACCT 2970': {'ACCT 1010', 'FNCE 1010'},
#  'ACCT 3990': set(),
#  'ACCT 6110': set(),
#  'ACCT 6130': set(),
#  'ACCT 7060': {'ACCT 6110'},
#  'ACCT 7420': {'ACCT 6110'},
#  'ACCT 7430': {'ACCT 6110'},
#  'ACCT 7470': {'ACCT 6110'},
#  'ACCT 7471': {'ACCT 6110'},
#  'ACCT 7640': {'ACCT 6110', 'MGEC 6110', 'MGEC 6120'},
#  'ACCT 8970': {'ACCT 6110', 'FNCE 6110'},
#  'ACCT 9300': set(),
#  'ACCT 9400': set(),
#  'ACCT 9410': set(),
#  'ACCT 9420': set(),
#  'ACCT 9430': set(),
#  'ACCT 9810': set(),
#  'ACCT 9820': set(),
#  'AFRC 0008': set(),
#  'AFRC 0010': set(),
#  'AFRC 0012': set(),
#  'AFRC 0013': set(),
#  'AFRC 0015': set(),
#  'AFRC 0030': set(),
#  'AFRC 0081': set(),
#  'AFRC 0082': set(),
#  'AFRC 0100': set(),
#  'AFRC 0200': set(),
#  'AFRC 0300': set(),
#  'AFRC 0320': set(),
#  'AFRC 0350': set(),
#  'AFRC 0400': set(),
#  'AFRC 0496': set(),
#  'AFRC 0521': set(),
#  'AFRC 1000': set(),
#  'AFRC 1001': set(),
#  'AFRC 1002': set(),
#  'AFRC 1019': set(),
#  'AFRC 1060': set(),
#  'AFRC 1090': set(),
#  'AFRC 1092': set(),
#  'AFRC 1100': set(),
#  'AFRC 1115': set(),
#  'AFRC 1117': set(),
#  'AFRC 1119': set(),
#  'AFRC 1120': set(),
#  'AFRC 1121': set(),
#  'AFRC 1122': set(),
#  'AFRC 1123': set(),
#  'AFRC 1130': set(),
#  'AFRC 1131': set(),
#  'AFRC 1151': set(),
#  'AFRC 1160': set(),
#  'AFRC 1169': set(),
#  'AFRC 1172': set(),
#  'AFRC 1176': set(),
#  'AFRC 1177': set(),
#  'AFRC 1187': set(),
#  'AFRC 1200': set(),
#  'AFRC 1201': set(),
#  'AFRC 1202': set(),
#  'AFRC 1205': set(),
#  'AFRC 1206': set(),
#  'AFRC 1210': set(),
#  'AFRC 1220': set(),
#  'AFRC 1310': set(),
#  'AFRC 1350': set(),
#  'AFRC 1358': set(),
#  'AFRC 1370': set(),
#  'AFRC 1400': set(),
#  'AFRC 1475': set(),
#  'AFRC 1500': set(),
#  'AFRC 1510': set(),
#  'AFRC 1560': set(),
#  'AFRC 1600': set(),
#  'AFRC 1625': set(),
#  'AFRC 1700': set(),
#  'AFRC 1780': set(),
#  'AFRC 1810': set(),
#  'AFRC 1880': set(),
#  'AFRC 2010': set(),
#  'AFRC 2140': set(),
#  'AFRC 2180': set(),
#  'AFRC 2200': set(),
#  'AFRC 2210': set(),
#  'AFRC 2211': set(),
#  'AFRC 2219': set(),
#  'AFRC 2220': set(),
#  'AFRC 2229': set(),
#  'AFRC 2232': set(),
#  'AFRC 2238': set(),
#  'AFRC 2240': set(),
#  'AFRC 2245': set(),
#  'AFRC 2250': set(),
#  'AFRC 2251': set(),
#  'AFRC 2302': set(),
#  'AFRC 2310': set(),
#  'AFRC 2321': set(),
#  'AFRC 2324': set(),
#  'AFRC 2325': set(),
#  'AFRC 2350': set(),
#  'AFRC 2401': set(),
#  'AFRC 2402': set(),
#  'AFRC 2430': set(),
#  'AFRC 2542': set(),
#  'AFRC 2545': set(),
#  'AFRC 2630': set(),
#  'AFRC 2670': set(),
#  'AFRC 2709': set(),
#  'AFRC 2740': set(),
#  'AFRC 2760': set(),
#  'AFRC 2762': set(),
#  'AFRC 2781': set(),
#  'AFRC 2850': set(),
#  'AFRC 2851': set(),
#  'AFRC 2852': set(),
#  'AFRC 2860': set(),
#  'AFRC 2870': set(),
#  'AFRC 2903': set(),
#  'AFRC 3051': set(),
#  'AFRC 3101': set(),
#  'AFRC 3106': set(),
#  'AFRC 3110': set(),
#  'AFRC 3112': set(),
#  'AFRC 3151': set(),
#  'AFRC 3152': set(),
#  'AFRC 3173': set(),
#  'AFRC 3174': set(),
#  'AFRC 3180': set(),
#  'AFRC 3230': set(),
#  'AFRC 3251': set(),
#  'AFRC 3253': set(),
#  'AFRC 3255': set(),
#  'AFRC 3257': set(),
#  'AFRC 3305': set(),
#  'AFRC 3306': set(),
#  'AFRC 3336': set(),
#  'AFRC 3340': set(),
#  'AFRC 3343': set(),
#  'AFRC 3350': set(),
#  'AFRC 3351': set(),
#  'AFRC 3386': set(),
#  'AFRC 3408': set(),
#  'AFRC 3450': set(),
#  'AFRC 3452': set(),
#  'AFRC 3455': set(),
#  'AFRC 3460': set(),
#  'AFRC 3500': set(),
#  'AFRC 3510': set(),
#  'AFRC 3511': set(),
#  'AFRC 3515': set(),
#  'AFRC 3540': set(),
#  'AFRC 3550': set(),
#  'AFRC 3560': set(),
#  'AFRC 3561': set(),
#  'AFRC 3570': set(),
#  'AFRC 3580': set(),
#  'AFRC 3665': set(),
#  'AFRC 3700': set(),
#  'AFRC 3770': set(),
#  'AFRC 3804': set(),
#  'AFRC 3812': set(),
#  'AFRC 3814': set(),
#  'AFRC 3840': set(),
#  'AFRC 3930': set(),
#  'AFRC 3931': set(),
#  'AFRC 3932': set(),
#  'AFRC 3999': set(),
#  'AFRC 4000': set(),
#  'AFRC 4050': set(),
#  'AFRC 4200': set(),
#  'AFRC 4322': set(),
#  'AFRC 4327': set(),
#  'AFRC 4387': set(),
#  'AFRC 4400': set(),
#  'AFRC 4404': set(),
#  'AFRC 4406': set(),
#  'AFRC 4431': set(),
#  'AFRC 4480': set(),
#  'AFRC 4500': set(),
#  'AFRC 4605': set(),
#  'AFRC 4650': set(),
#  'AFRC 4800': set(),
#  'AFRC 4880': set(),
#  'AFRC 4920': set(),
#  'AFRC 4990': set(),
#  'AFRC 5020': set(),
#  'AFRC 5030': set(),
#  'AFRC 5060': set(),
#  'AFRC 5091': set(),
#  'AFRC 5100': set(),
#  'AFRC 5140': set(),
#  'AFRC 5170': set(),
#  'AFRC 5220': set(),
#  'AFRC 5229': set(),
#  'AFRC 5240': set(),
#  'AFRC 5270': set(),
#  'AFRC 5300': set(),
#  'AFRC 5310': set(),
#  'AFRC 5330': set(),
#  'AFRC 5420': set(),
#  'AFRC 5470': set(),
#  'AFRC 5490': set(),
#  'AFRC 5500': set(),
#  'AFRC 5573': set(),
#  'AFRC 5600': set(),
#  'AFRC 5700': set(),
#  'AFRC 5701': set(),
#  'AFRC 5710': set(),
#  'AFRC 5791': set(),
#  'AFRC 5792': set(),
#  'AFRC 5900': set(),
#  'AFRC 5910': set(),
#  'AFRC 6020': set(),
#  'AFRC 6140': set(),
#  'AFRC 6200': set(),
#  'AFRC 6240': set(),
#  'AFRC 6400': set(),
#  'AFRC 6401': set(),
#  'AFRC 6410': set(),
#  'AFRC 6450': set(),
#  'AFRC 6542': set(),
#  'AFRC 6550': set(),
#  'AFRC 6552': set(),
#  'AFRC 6560': set(),
#  'AFRC 6620': set(),
#  'AFRC 6665': set(),
#  'AFRC 6740': set(),
#  'AFRC 6750': {'ANEL 4500'},
#  'AFRC 6770': set(),
#  'AFRC 6781': set(),
#  'AFRC 6804': set(),
#  'AFRC 6850': set(),
#  'AFRC 6910': set(),
#  'AFRC 6971': set(),
#  'AFRC 7010': set(),
#  'AFRC 7060': set(),
#  'AFRC 7080': set(),
#  'AFRC 7100': set(),
#  'AFRC 7200': set(),
#  'AFRC 7230': set(),
#  'AFRC 7400': set(),
#  'AFRC 7708': set(),
#  'AFRC 7910': set(),
#  'AFRC 7920': set(),
#  'AFRC 9005': set(),
#  'AFRC 9006': set(),
#  'AFRC 9016': set(),
#  'AFRC 9017': set(),
#  'ASLD 0100': set(),
#  'ASLD 0200': {'ASLD 0100'},
#  'ASLD 0300': {'ASLD 0200'},
#  'ASLD 0340': {'ASLD 0200'},
#  'ASLD 0400': {'ASLD 0300'},
#  'ASLD 1030': {'ASLD 0400'},
#  'ASLD 1031': {'ASLD 0400'},
#  'ASLD 1032': set(),
#  'ASLD 1033': {'ASLD 1032'},
#  'ASLD 1039': set(),
#  'ASLD 2047': {'LING 0001'},
#  'ASLD 5999': set(),
#  'AMHR 0100': set(),
#  'AMHR 0200': {'AMHR 0100'},
#  'AMHR 0300': set(),
#  'AMHR 0400': set(),
#  'AMHR 1100': set(),
#  'AMHR 1300': set(),
#  'ANAT 5050': set(),
#  'ANAT 5120': set(),
#  'ANAT 5130': set(),
#  'ANAT 5140': set(),
#  'ANAT 5150': set(),
#  'ANAT 5160': set(),
#  'ANAT 5170': set(),
#  'ANAT 5180': set(),
#  'ANAT 5190': set(),
#  'ANCH 0020': set(),
#  'ANCH 0100': set(),
#  'ANCH 0101': set(),
#  'ANCH 0102': set(),
#  'ANCH 1100': set(),
#  'ANCH 1102': set(),
#  'ANCH 1103': set(),
#  'ANCH 1202': set(),
#  'ANCH 1203': set(),
#  'ANCH 1205': set(),
#  'ANCH 1206': set(),
#  'ANCH 1207': set(),
#  'ANCH 1305': set(),
#  'ANCH 3101': set(),
#  'ANCH 3102': set(),
#  'ANCH 3103': set(),
#  'ANCH 3104': set(),
#  'ANCH 3107': set(),
#  'ANCH 3109': set(),
#  'ANCH 3201': set(),
#  'ANCH 3203': set(),
#  'ANCH 3204': set(),
#  'ANCH 3205': set(),
#  'ANCH 3206': set(),
#  'ANCH 3207': set(),
#  'ANCH 3209': set(),
#  'ANCH 3210': set(),
#  'ANCH 3602': set(),
#  'ANCH 3999': set(),
#  'ANCH 4998': set(),
#  'ANCH 5800': set(),
#  'ANCH 6080': set(),
#  'ANCH 6101': set(),
#  'ANCH 6102': set(),
#  'ANCH 6103': set(),
#  'ANCH 7202': set(),
#  'ANCH 7203': set(),
#  'ANCH 7204': set(),
#  'ANCH 7205': set(),
#  'ANCH 7208': set(),
#  'ANCH 7209': set(),
#  'ANCH 7210': set(),
#  'ANCH 7310': set(),
#  'ANCH 7403': set(),
#  'ANCH 9000': set(),
#  'ANCH 9999': set(),
#  'ANEL 4000': set(),
#  'ANEL 4100': {'ANEL 4000'},
#  'ANEL 4200': set(),
#  'ANEL 4250': set(),
#  'ANEL 4300': set(),
#  'ANEL 4420': set(),
#  'ANEL 4500': set(),
#  'ANEL 4600': {'ANEL 4500'},
#  'ANEL 6000': set(),
#  'ANEL 6100': {'ANEL 6000'},
#  'ANEL 6250': {'ANEL 6100'},
#  'ANEL 6300': {'ANEL 6100'},
#  'ANEL 6350': {'ANEL 6100'},
#  'ANEL 6400': set(),
#  'ANEL 6650': set(),
#  'ANEL 6700': {'ANEL 4500'},
#  'ANEL 6750': {'ANEL 4500'},
#  'ANEL 6800': set(),
#  'ANEL 7000': {'ANEL 6100'},
#  'ANEL 7200': set(),
#  'ANEL 7300': set(),
#  'ANEL 7400': {'ANEL 6100'},
#  'ANEL 7430': {'ANEL 6100'},
#  'ANEL 7500': {'ANEL 6100'},
#  'ANEL 7600': {'ANEL 6100'},
#  'ANEL 7700': {'ANEL 7200'},
#  'ANTH 0002': set(),
#  'ANTH 0020': set(),
#  'ANTH 0030': set(),
#  'ANTH 0040': set(),
#  'ANTH 0050': set(),
#  'ANTH 0058': set(),
#  'ANTH 0063': set(),
#  'ANTH 0091': set(),
#  'ANTH 0103': set(),
#  'ANTH 0105': set(),
#  'ANTH 0111': set(),
#  'ANTH 0120': set(),
#  'ANTH 0184': set(),
#  'ANTH 0330': set(),
#  'ANTH 0630': set(),
#  'ANTH 0905': set(),
#  'ANTH 0930': set(),
#  'ANTH 1002': set(),
#  'ANTH 1020': set(),
#  'ANTH 1040': set(),
#  'ANTH 1104': set(),
#  'ANTH 1120': set(),
#  'ANTH 1140': set(),
#  'ANTH 1151': set(),
#  'ANTH 1160': set(),
#  'ANTH 1169': set(),
#  'ANTH 1171': set(),
#  'ANTH 1202': set(),
#  'ANTH 1219': set(),
#  'ANTH 1230': set(),
#  'ANTH 1238': set(),
#  'ANTH 1300': set(),
#  'ANTH 1303': set(),
#  'ANTH 1310': set(),
#  'ANTH 1340': set(),
#  'ANTH 1410': set(),
#  'ANTH 1430': set(),
#  'ANTH 1440': set(),
#  'ANTH 1480': set(),
#  'ANTH 1490': set(),
#  'ANTH 1500': set(),
#  'ANTH 1533': set(),
#  'ANTH 1560': set(),
#  'ANTH 1610': set(),
#  'ANTH 1630': set(),
#  'ANTH 1670': set(),
#  'ANTH 1688': set(),
#  'ANTH 1755': set(),
#  'ANTH 1900': set(),
#  'ANTH 1905': set(),
#  'ANTH 1925': set(),
#  'ANTH 2020': set(),
#  'ANTH 2024': set(),
#  'ANTH 2060': set(),
#  'ANTH 2070': set(),
#  'ANTH 2080': set(),
#  'ANTH 2109': set(),
#  'ANTH 2110': set(),
#  'ANTH 2120': set(),
#  'ANTH 2145': set(),
#  'ANTH 2150': set(),
#  'ANTH 2154': set(),
#  'ANTH 2221': set(),
#  'ANTH 2267': set(),
#  'ANTH 2307': set(),
#  'ANTH 2308': set(),
#  'ANTH 2317': set(),
#  'ANTH 2327': set(),
#  'ANTH 2329': set(),
#  'ANTH 2330': set(),
#  'ANTH 2332': set(),
#  'ANTH 2338': set(),
#  'ANTH 2340': set(),
#  'ANTH 2440': set(),
#  'ANTH 2450': set(),
#  'ANTH 2460': set(),
#  'ANTH 2490': set(),
#  'ANTH 2515': set(),
#  'ANTH 2540': set(),
#  'ANTH 2550': set(),
#  'ANTH 2560': set(),
#  'ANTH 2570': set(),
#  'ANTH 2590': set(),
#  'ANTH 2730': set(),
#  'ANTH 2762': set(),
#  'ANTH 2790': set(),
#  'ANTH 2840': set(),
#  'ANTH 2940': set(),
#  'ANTH 2970': set(),
#  'ANTH 2978': set(),
#  'ANTH 3015': set(),
#  'ANTH 3022': set(),
#  'ANTH 3030': set(),
#  'ANTH 3045': set(),
#  'ANTH 3050': set(),
#  'ANTH 3052': set(),
#  'ANTH 3090': set(),
#  'ANTH 3101': set(),
#  'ANTH 3110': set(),
#  'ANTH 3130': set(),
#  'ANTH 3137': set(),
#  'ANTH 3180': set(),
#  'ANTH 3215': set(),
#  'ANTH 3219': set(),
#  'ANTH 3221': set(),
#  'ANTH 3230': set(),
#  'ANTH 3235': set(),
#  'ANTH 3240': set(),
#  'ANTH 3244': set(),
#  'ANTH 3307': set(),
#  'ANTH 3310': set(),
#  'ANTH 3328': set(),
#  'ANTH 3340': set(),
#  'ANTH 3360': set(),
#  'ANTH 3368': set(),
#  'ANTH 3376': set(),
#  'ANTH 3390': set(),
#  'ANTH 3407': set(),
#  'ANTH 3420': set(),
#  'ANTH 3424': set(),
#  'ANTH 3429': set(),
#  'ANTH 3444': set(),
#  'ANTH 3447': set(),
#  'ANTH 3451': set(),
#  'ANTH 3454': set(),
#  'ANTH 3470': set(),
#  'ANTH 3480': set(),
#  'ANTH 3520': set(),
#  'ANTH 3540': set(),
#  'ANTH 3664': set(),
#  'ANTH 3665': set(),
#  'ANTH 3690': set(),
#  'ANTH 3766': set(),
#  'ANTH 3770': set(),
#  'ANTH 3780': set(),
#  'ANTH 3804': set(),
#  'ANTH 3820': set(),
#  'ANTH 3910': set(),
#  'ANTH 3930': {'SPAN 1800', 'SPAN 1900'},
#  'ANTH 3999': set(),
#  'ANTH 4000': set(),
#  'ANTH 4010': set(),
#  'ANTH 5024': set(),
#  'ANTH 5026': set(),
#  'ANTH 5080': set(),
#  'ANTH 5110': set(),
#  'ANTH 5137': set(),
#  'ANTH 5211': set(),
#  'ANTH 5215': set(),
#  'ANTH 5219': set(),
#  'ANTH 5220': set(),
#  'ANTH 5221': set(),
#  'ANTH 5230': set(),
#  'ANTH 5231': set(),
#  'ANTH 5235': set(),
#  'ANTH 5239': set(),
#  'ANTH 5240': set(),
#  'ANTH 5244': set(),
#  'ANTH 5267': set(),
#  'ANTH 5320': set(),
#  'ANTH 5360': set(),
#  'ANTH 5407': set(),
#  'ANTH 5410': set(),
#  'ANTH 5424': set(),
#  'ANTH 5429': set(),
#  'ANTH 5433': set(),
#  'ANTH 5440': set(),
#  'ANTH 5444': set(),
#  'ANTH 5447': set(),
#  'ANTH 5451': set(),
#  'ANTH 5454': set(),
#  'ANTH 5460': set(),
#  'ANTH 5467': set(),
#  'ANTH 5470': set(),
#  'ANTH 5480': set(),
#  'ANTH 5490': set(),
#  'ANTH 5500': set(),
#  'ANTH 5510': set(),
#  'ANTH 5564': set(),
#  'ANTH 5570': set(),
#  'ANTH 5669': set(),
#  'ANTH 5700': set(),
#  'ANTH 5720': set(),
#  'ANTH 5770': set(),
#  'ANTH 5780': set(),
#  'ANTH 5805': set(),
#  'ANTH 5809': set(),
#  'ANTH 5830': set(),
#  'ANTH 5840': set(),
#  'ANTH 5857': set(),
#  'ANTH 5893': set(),
#  'ANTH 5898': set(),
#  'ANTH 5910': set(),
#  'ANTH 5940': set(),
#  'ANTH 5970': set(),
#  'ANTH 6000': set(),
#  'ANTH 6010': set(),
#  'ANTH 6020': set(),
#  'ANTH 6030': set(),
#  'ANTH 6070': set(),
#  'ANTH 6090': set(),
#  'ANTH 6110': set(),
#  'ANTH 6180': set(),
#  'ANTH 6200': set(),
#  'ANTH 6220': set(),
#  'ANTH 6260': set(),
#  'ANTH 6280': set(),
#  'ANTH 6307': set(),
#  'ANTH 6329': set(),
#  'ANTH 6340': set(),
#  'ANTH 6420': set(),
#  'ANTH 6460': set(),
#  'ANTH 6530': set(),
#  'ANTH 6550': set(),
#  'ANTH 6552': set(),
#  'ANTH 6570': set(),
#  'ANTH 6580': set(),
#  'ANTH 6664': set(),
#  'ANTH 6665': set(),
#  'ANTH 6770': set(),
#  'ANTH 6804': set(),
#  'ANTH 6840': set(),
#  'ANTH 6980': set(),
#  'ANTH 6990': set(),
#  'ANTH 6999': set(),
#  'ANTH 7000': set(),
#  'ANTH 7030': set(),
#  'ANTH 7040': {'EDUC 5495'},
#  'ANTH 7070': set(),
#  'ANTH 7307': set(),
#  'ANTH 7410': set(),
#  'ANTH 7701': set(),
#  'ANTH 7704': set(),
#  'AMCS 5100': set(),
#  'AMCS 5141': {'MATH 2400'},
#  'AMCS 5200': {'MATH 2400'},
#  'AMCS 5250': {'MATH 2400'},
#  'AMCS 5461': set(),
#  'AMCS 5670': set(),
#  'AMCS 5681': set(),
#  'AMCS 5840': {'MATH 1410'},
#  'AMCS 5999': set(),
#  'AMCS 6025': set(),
#  'AMCS 6035': set(),
#  'AMCS 6081': {'MATH 5080', 'MATH 5090'},
#  'AMCS 6091': {'MATH 6080'},
#  'AMCS 6481': {'STAT 4300'},
#  'AMCS 6491': set(),
#  'AMCS 8105': set(),
#  'AMCS 9999': set(),
#  'APOP 1000': set(),
#  'APOP 1200': set(),
#  'APOP 2000': set(),
#  'APOP 2200': set(),
#  'APOP 2900': set(),
#  'APOP 3200': set(),
#  'APOP 3400': set(),
#  'ARAB 0100': set(),
#  'ARAB 0120': set(),
#  'ARAB 0200': {'ARAB 0100'},
#  'ARAB 0220': {'ARAB 0120'},
#  'ARAB 0250': set(),
#  'ARAB 0300': {'ARAB 0200'},
#  'ARAB 0320': set(),
#  'ARAB 0400': {'ARAB 0300'},
#  'ARAB 0420': {'ARAB 0320'},
#  'ARAB 0450': set(),
#  'ARAB 0500': {'ARAB 0400'},
#  'ARAB 0600': {'ARAB 0500'},
#  'ARAB 0650': set(),
#  'ARAB 0700': set(),
#  'ARAB 2198': set(),
#  'ARAB 4000': {'ARAB 0600'},
#  'ARAB 4020': {'ARAB 0600'},
#  'ARAB 4030': {'ARAB 0200'},
#  'ARAB 4040': {'ARAB 0500'},
#  'ARAB 4050': {'ARAB 0600'},
#  'ARAB 4060': {'ARAB 0600'},
#  'ARAB 4070': set(),
#  'ARAB 4080': {'ARAB 0600'},
#  'ARAB 4090': set(),
#  'ARAB 5030': set(),
#  'ARAB 5300': {'ARAB 0600'},
#  'ARAB 5400': {'ARAB 0600'},
#  'ARAB 6100': set(),
#  'ARAB 6200': {'ARAB 6100'},
#  'ARAB 6300': {'ARAB 6200'},
#  'ARAB 6400': {'ARAB 6300'},
#  'ARAB 6500': set(),
#  'ARAB 6600': {'ARAB 6500'},
#  'ARAB 6720': {'ARAB 0200'},
#  'ARAB 6750': set(),
#  'ARAB 6800': {'ARAB 6600'},
#  'ARAB 7000': {'ARAB 4080'},
#  'ARAB 7020': {'ARAB 0600'},
#  'ARAB 7030': set(),
#  'ARAB 7100': set(),
#  'ARCH 0110': set(),
#  'ARCH 0111': set(),
#  'ARCH 0318': set(),
#  'ARCH 1010': set(),
#  'ARCH 1020': set(),
#  'ARCH 2010': {'ARCH 1010', 'ARCH 1020'},
#  'ARCH 2020': {'ARCH 2010'},
#  'ARCH 3010': {'ARCH 2020'},
#  'ARCH 3020': {'ARCH 3010'},
#  'ARCH 3030': set(),
#  'ARCH 3101': set(),
#  'ARCH 3110': set(),
#  'ARCH 4010': {'ARCH 3020'},
#  'ARCH 4020': set(),
#  'ARCH 4110': set(),
#  'ARCH 4120': {'ARCH 4110'},
#  'ARCH 4310': set(),
#  'ARCH 4320': set(),
#  'ARCH 4330': set(),
#  'ARCH 4350': set(),
#  'ARCH 4360': set(),
#  'ARCH 4998': {'ARCH 3010'},
#  'ARCH 5000': set(),
#  'ARCH 5010': set(),
#  'ARCH 5020': set(),
#  'ARCH 5110': set(),
#  'ARCH 5120': set(),
#  'ARCH 5210': set(),
#  'ARCH 5220': set(),
#  'ARCH 5310': set(),
#  'ARCH 5320': set(),
#  'ARCH 5350': set(),
#  'ARCH 5360': set(),
#  'ARCH 5990': set(),
#  'ARCH 6010': set(),
#  'ARCH 6020': set(),
#  'ARCH 6110': set(),
#  'ARCH 6210': set(),
#  'ARCH 6310': set(),
#  'ARCH 6330': set(),
#  'ARCH 6340': set(),
#  'ARCH 6360': set(),
#  'ARCH 6710': set(),
#  'ARCH 6741': set(),
#  'ARCH 6850': set(),
#  'ARCH 6980': set(),
#  'ARCH 6999': set(),
#  'ARCH 7010': set(),
#  'ARCH 7030': set(),
#  'ARCH 7040': set(),
#  'ARCH 7050': set(),
#  'ARCH 7060': set(),
#  'ARCH 7070': set(),
#  'ARCH 7080': {'ARCH 7510', 'ARCH 7520', 'ARCH 7530'},
#  'ARCH 7090': {'ARCH 7080', 'ARCH 7510', 'ARCH 7520', 'ARCH 7530'},
#  'ARCH 7100': set(),
#  'ARCH 7110': set(),
#  'ARCH 7120': set(),
#  'ARCH 7121': set(),
#  'ARCH 7122': set(),
#  'ARCH 7123': set(),
#  'ARCH 7130': set(),
#  'ARCH 7140': set(),
#  'ARCH 7150': set(),
#  'ARCH 7180': set(),
#  'ARCH 7190': set(),
#  'ARCH 7200': set(),
#  'ARCH 7210': set(),
#  'ARCH 7240': set(),
#  'ARCH 7250': set(),
#  'ARCH 7260': set(),
#  'ARCH 7280': set(),
#  'ARCH 7300': set(),
#  'ARCH 7310': set(),
#  'ARCH 7320': set(),
#  'ARCH 7321': set(),
#  'ARCH 7322': set(),
#  'ARCH 7323': set(),
#  'ARCH 7324': set(),
#  'ARCH 7325': set(),
#  'ARCH 7326': set(),
#  'ARCH 7330': set(),
#  'ARCH 7340': set(),
#  'ARCH 7360': set(),
#  'ARCH 7361': set(),
#  'ARCH 7362': set(),
#  'ARCH 7363': set(),
#  'ARCH 7370': set(),
#  'ARCH 7371': set(),
#  'ARCH 7380': set(),
#  'ARCH 7390': set(),
#  'ARCH 7410': set(),
#  'ARCH 7420': set(),
#  'ARCH 7430': set(),
#  'ARCH 7440': set(),
#  'ARCH 7460': set(),
#  'ARCH 7470': set(),
#  'ARCH 7480': set(),
#  'ARCH 7490': set(),
#  'ARCH 7500': set(),
#  'ARCH 7510': set(),
#  'ARCH 7520': set(),
#  'ARCH 7530': set(),
#  'ARCH 7540': {'ARCH 7530'},
#  'ARCH 7550': set(),
#  'ARCH 7580': set(),
#  'ARCH 7610': set(),
#  'ARCH 7620': set(),
#  'ARCH 7650': set(),
#  'ARCH 7680': {'REAL 7210'},
#  'ARCH 7710': set(),
#  'ARCH 7820': set(),
#  'ARCH 7910': set(),
#  'ARCH 7920': set(),
#  'ARCH 7930': set(),
#  'ARCH 7940': set(),
#  'ARCH 7990': set(),
#  'ARCH 8000': set(),
#  'ARCH 8010': set(),
#  'ARCH 8011': set(),
#  'ARCH 8020': set(),
#  'ARCH 8030': set(),
#  'ARCH 8040': set(),
#  'ARCH 8050': set(),
#  'ARCH 8060': set(),
#  'ARCH 8070': set(),
#  'ARCH 8080': set(),
#  'ARCH 8110': set(),
#  'ARCH 8120': set(),
#  'ARCH 8130': set(),
#  'ARCH 8140': set(),
#  'ARCH 8150': set(),
#  'ARCH 8160': set(),
#  'ARCH 8510': set(),
#  'ARCH 8520': set(),
#  'ARCH 9950': set(),
#  'ARCH 9980': set(),
#  'ARCH 9999': set(),
#  'AAMW 5020': set(),
#  'AAMW 5120': set(),
#  'AAMW 5190': set(),
#  'AAMW 5200': set(),
#  'AAMW 5220': set(),
#  'AAMW 5230': set(),
#  'AAMW 5231': set(),
#  'AAMW 5239': set(),
#  'AAMW 5241': set(),
#  'AAMW 5250': set(),
#  'AAMW 5251': set(),
#  'AAMW 5252': set(),
#  'AAMW 5253': set(),
#  'AAMW 5254': set(),
#  'AAMW 5260': set(),
#  'AAMW 5290': set(),
#  'AAMW 5291': set(),
#  'AAMW 5292': set(),
#  'AAMW 5293': set(),
#  'AAMW 5305': set(),
#  'AAMW 5320': set(),
#  'AAMW 5321': set(),
#  'AAMW 5322': set(),
#  'AAMW 5323': set(),
#  'AAMW 5360': set(),
#  'AAMW 5390': set(),
#  'AAMW 5400': set(),
#  'AAMW 5420': set(),
#  'AAMW 5460': {'CLST 6300'},
#  'AAMW 5500': set(),
#  'AAMW 5570': set(),
#  'AAMW 5590': set(),
#  'AAMW 5620': set(),
#  'AAMW 5630': set(),
#  'AAMW 5720': set(),
#  'AAMW 6130': set(),
#  'AAMW 6141': set(),
#  'AAMW 6180': set(),
#  'AAMW 6190': set(),
#  'AAMW 6220': set(),
#  'AAMW 6221': set(),
#  'AAMW 6240': set(),
#  'AAMW 6250': set(),
#  'AAMW 6260': set(),
#  'AAMW 6269': set(),
#  'AAMW 6280': set(),
#  'AAMW 6290': set(),
#  'AAMW 6300': set(),
#  'AAMW 6320': set(),
#  'AAMW 6330': set(),
#  'AAMW 6350': set(),
#  'AAMW 6400': set(),
#  'AAMW 6425': set(),
#  'AAMW 6426': set(),
#  'AAMW 6427': set(),
#  'AAMW 6428': set(),
#  'AAMW 6470': set(),
#  'AAMW 7050': set(),
#  'AAMW 7200': set(),
#  'AAMW 7220': set(),
#  'AAMW 7230': set(),
#  'AAMW 7240': set(),
#  'AAMW 7259': set(),
#  'AAMW 7260': set(),
#  'AAMW 7320': set(),
#  'AAMW 7350': set(),
#  'AAMW 7370': set(),
#  'AAMW 7400': set(),
#  'AAMW 7401': set(),
#  'AAMW 7510': set(),
#  'AAMW 8000': set(),
#  'AAMW 9999': set(),
#  'ARTH 0127': set(),
#  'ARTH 0141': set(),
#  'ARTH 0143': set(),
#  'ARTH 0221': set(),
#  'ARTH 0339': set(),
#  'ARTH 0500': set(),
#  'ARTH 0501': set(),
#  'ARTH 1010': set(),
#  'ARTH 1020': set(),
#  'ARTH 1030': set(),
#  'ARTH 1040': set(),
#  'ARTH 1060': set(),
#  'ARTH 1070': set(),
#  'ARTH 1080': set(),
#  'ARTH 1090': set(),
#  'ARTH 1100': set(),
#  'ARTH 1500': set(),
#  'ARTH 1800': set(),
#  'ARTH 2094': set(),
#  'ARTH 2120': set(),
#  'ARTH 2130': set(),
#  'ARTH 2140': set(),
#  'ARTH 2145': set(),
#  'ARTH 2170': set(),
#  'ARTH 2180': set(),
#  'ARTH 2200': set(),
#  'ARTH 2220': set(),
#  'ARTH 2221': set(),
#  'ARTH 2240': set(),
#  'ARTH 2250': set(),
#  'ARTH 2260': set(),
#  'ARTH 2269': set(),
#  'ARTH 2290': set(),
#  'ARTH 2320': set(),
#  'ARTH 2330': set(),
#  'ARTH 2350': set(),
#  'ARTH 2370': set(),
#  'ARTH 2400': set(),
#  'ARTH 2450': set(),
#  'ARTH 2451': set(),
#  'ARTH 2500': set(),
#  'ARTH 2540': set(),
#  'ARTH 2541': set(),
#  'ARTH 2542': set(),
#  'ARTH 2580': set(),
#  'ARTH 2610': set(),
#  'ARTH 2620': set(),
#  'ARTH 2670': set(),
#  'ARTH 2679': set(),
#  'ARTH 2680': set(),
#  'ARTH 2699': set(),
#  'ARTH 2700': set(),
#  'ARTH 2710': set(),
#  'ARTH 2730': set(),
#  'ARTH 2740': set(),
#  'ARTH 2750': set(),
#  'ARTH 2760': set(),
#  'ARTH 2770': set(),
#  'ARTH 2780': set(),
#  'ARTH 2781': set(),
#  'ARTH 2810': set(),
#  'ARTH 2850': set(),
#  'ARTH 2860': set(),
#  'ARTH 2870': set(),
#  'ARTH 2879': set(),
#  'ARTH 2889': set(),
#  'ARTH 2900': set(),
#  'ARTH 2910': set(),
#  'ARTH 2920': set(),
#  'ARTH 2930': set(),
#  'ARTH 2940': set(),
#  'ARTH 2950': set(),
#  'ARTH 2960': set(),
#  'ARTH 3000': set(),
#  'ARTH 3020': set(),
#  'ARTH 3030': set(),
#  'ARTH 3060': set(),
#  'ARTH 3070': set(),
#  'ARTH 3071': set(),
#  'ARTH 3100': set(),
#  'ARTH 3120': set(),
#  'ARTH 3130': set(),
#  'ARTH 3131': set(),
#  'ARTH 3150': set(),
#  'ARTH 3170': set(),
#  'ARTH 3180': set(),
#  'ARTH 3200': set(),
#  'ARTH 3230': set(),
#  'ARTH 3250': set(),
#  'ARTH 3251': set(),
#  'ARTH 3252': set(),
#  'ARTH 3290': set(),
#  'ARTH 3291': set(),
#  'ARTH 3292': set(),
#  'ARTH 3305': set(),
#  'ARTH 3320': set(),
#  'ARTH 3321': set(),
#  'ARTH 3330': set(),
#  'ARTH 3400': set(),
#  'ARTH 3401': set(),
#  'ARTH 3430': set(),
#  'ARTH 3500': set(),
#  'ARTH 3510': set(),
#  'ARTH 3511': set(),
#  'ARTH 3512': set(),
#  'ARTH 3560': set(),
#  'ARTH 3620': set(),
#  'ARTH 3621': set(),
#  'ARTH 3630': set(),
#  'ARTH 3730': set(),
#  'ARTH 3749': set(),
#  'ARTH 3750': set(),
#  'ARTH 3790': set(),
#  'ARTH 3820': set(),
#  'ARTH 3830': set(),
#  'ARTH 3831': set(),
#  'ARTH 3840': set(),
#  'ARTH 3850': set(),
#  'ARTH 3860': set(),
#  'ARTH 3870': set(),
#  'ARTH 3871': set(),
#  'ARTH 3873': set(),
#  'ARTH 3874': set(),
#  'ARTH 3880': set(),
#  'ARTH 3900': set(),
#  'ARTH 3901': set(),
#  'ARTH 3902': set(),
#  'ARTH 3910': set(),
#  'ARTH 3911': set(),
#  'ARTH 3912': set(),
#  'ARTH 3913': set(),
#  'ARTH 3914': set(),
#  ...}
